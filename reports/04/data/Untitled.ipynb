# %%
import pandas as pd
import numpy as np
df = pd.read_csv('measurements_2.csv', sep=';', skiprows = 1, names=['platform', 'device', 'work_x', 'work_y', 'ex1', 'ov1','ex2', 'ov2','ex3', 'ov3','ex4', 'ov4', 'ex5', 'ov5'])

# %%
data = df[['work_x', 'work_y']]
data['ex'] =  df[['ex1', 'ex2', 'ex3', 'ex4', 'ex5']].mean(axis=1)
data
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        work_x  work_y          ex
# 0           1       1  35314340.0
# 1           1       2  31194760.0
# 2           1       3  30762200.0
# 3           1       4  34857080.0
# 4           1       5  31738520.0
# 5           1       6  31551560.0
# 6           1       7  30942240.0
# 7           1       8  32539500.0
# 8           1       9  31440020.0
# 9           1      10  31453180.0
# 10          1      11  31444480.0
# 11          1      12  30887760.0
# 12          1      13  31038060.0
# 13          1      14  31633640.0
# 14          1      15  31393680.0
# 15          1      16  31231740.0
# 16          1      17  31436920.0
# 17          1      18  30556280.0
# 18          1      19  30986600.0
# 19          1      20  32364880.0
# 20          1      21  30925160.0
# 21          1      22  30932080.0
# 22          1      23  31324400.0
# 23          1      24  30892460.0
# 24          1      25  30362980.0
# 25          1      26  31104160.0
# 26          1      27  30261100.0
# 27          1      28  30716780.0
# 28          1      29  30593720.0
# 29          1      30  31518040.0
# ...       ...     ...         ...
# 16099     127      98  28299360.0
# 16100     127      99  28710380.0
# 16101     127     100  29335140.0
# 16102     127     101  29271540.0
# 16103     127     102  29664160.0
# 16104     127     103  26915200.0
# 16105     127     104  26909520.0
# 16106     127     105  27701680.0
# 16107     127     106  28156540.0
# 16108     127     107  28321740.0
# 16109     127     108  28538080.0
# 16110     127     109  28424760.0
# 16111     127     110  29304740.0
# 16112     127     111  28832460.0
# 16113     127     112  29512880.0
# 16114     127     113  30094780.0
# 16115     127     114  26521120.0
# 16116     127     115  27305440.0
# 16117     127     116  27667540.0
# 16118     127     117  27210580.0
# 16119     127     118  28448300.0
# 16120     127     119  27795600.0
# 16121     127     120  28403620.0
# 16122     127     121  28055480.0
# 16123     127     122  28516040.0
# 16124     127     123  28905200.0
# 16125     127     124  28844660.0
# 16126     127     125  28816680.0
# 16127     127     126  30082560.0
# 16128     127     127  30056120.0
#
# [16129 rows x 3 columns]

# %%
data = data.drop_duplicates(subset=['work_x', 'work_y'])
data
data = data.pivot('work_x', 'work_y', 'ex')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(9,7)) # does not affect the following plot

sns.set()
cmap = sns.cubehelix_palette(3, light=1, as_cmap=True)
ax = sns.heatmap(data, cmap=cmap, )
ax.invert_yaxis()
fig.savefig('output_powers.pdf')
